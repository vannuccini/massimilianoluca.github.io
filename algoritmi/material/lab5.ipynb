# %% [markdown]
# # Lab 5
# In this practical we will keep working with data structures. In particular, we will see a special data structure called *tree*.
#
# ## Trees
#
# Trees are data structures composed of two elements *nodes* and *edges*. Nodes represent *things* and edges represent *relationships* among **two** nodes.
#
# One node called the **root** is the top level of the tree and is connected to one or more other nodes. If the root is connected to another node by means of one edge, then it is said to be the **parent** of the node (and that node is the **child** of the root). Any node can be **parent** of one or more other nodes, the only important thing is that **all nodes have only one parent**. The **root is the only exception as it does not have any parent**. Some nodes do not have children and they are called **leaves**.
#
# An example of graph:
#
#
# ![](img/pract17/tree.png)
#
# As seen in the lecture, graphs can be defined recursively in the following way: *a tree is a root and zero or more subtrees,each of which is also a tree. The root of each subtree is connected to the root of the parent tree by an edge.*
#
# Graphically:
#
# ![](img/pract17/recursiveTree.png)
#
#
# Some properties of nodes and trees are:
#
# 1. The depth of a node N: the length of the path connecting the root to N counted as number of edges in the path.
#
# 2. The level (n) of a tree: set of nodes at the same depth (n).
#
# 3. Height : is the maximum depth of all leaves.
#
# 4. Width : the maximum number of nodes in each level.
#
# The following tree:
#
# ![](img/pract17/exampleTree.png)
#
# has four levels (0,1,2,3), height equal to 3 and width equal to 4.
#
#
# ## ADT: Binary Tree
#
# **Binary trees** are **trees** where each node has at most two children: the **right child** and the **left child**.
#
# ![](img/pract17/binaryPointers.png)
#
# The specifications of the binary tree ADT (from the lecture):
#
# ![](img/pract17/binarytreeADT.png)
#
# When implementing a tree we can define a node object and then a tree object that stores nodes, but we will use the more compact way which is to use the recursive definition of a tree.
#
# **Note:** if we want to keep attributes as private, we need to add another method to the previously seen methods: **myTree.setParent(tree)** that sets the parent of a tree **myTree** to **tree**.
#
# **Example:** Let's implement a binary tree using the recursive definition: a binary tree is a root --with a value --  connected to two subtrees, respectively the right and left subtree.

# %%
# %reset -f 

"""This could go to BinaryTree.py"""

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self) 
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None


    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    printTree(BT)
    print("\nDelete right branch of 2")
    bt2.deleteRight()
    printTree(BT)
    
    print("\nInsert left branch of 5")
    newN = BinaryTree("child of 5")
    bt5.insertLeft(newN)
    printTree(BT)
# Out:
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (r)-> 6
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
#
# Delete right branch of 2
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
#
# Insert left branch of 5
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
# 			5 (l)-> child of 5

# %% [markdown]
# Note that in the code above, deletion of right or left subtree means to just set the pointer to null. This destroys the whole subtree (more clever things can be done in some cases, especially with generic trees).
#
# Now we can see how to perform some visits of the trees, that is going through the nodes following the connections. In particular, there are two different types of visits: **depth first search** and **breadth first search**.
#
# ### Binary Tree visits: DFS
#
# Given a tree T, depth first search (DFS) visits all the subtrees of T going as deep as it can before going back and down another branch until all the tree is visited.
#
# DFS requires a stack and can be implemented recursively. What we do with the root during the visit defines 3 different types of visits:
#
# 1. the root is visited before the visiting the subtree : pre-order;
#
# 2. the root is visited after the left subtree but before the right subtree : in-order;
#
# 3. the root is visited after the left and right subtrees : post-order
#
#
# **Example:** Let's implement the three versions of the DFS and apply them to binary tree seen above.

# %%
class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self) 
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
   
    def preOrderDFS(self):
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            print(self.getValue())
            if l != None:
                l.preOrderDFS()
            if r != None:
                r.preOrderDFS()
    
    def inOrderDFS(self):
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            if l != None:
                l.inOrderDFS()
            print(self.getValue())
            
            if r != None:
                r.inOrderDFS()
            
    def postOrderDFS(self):
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            if l != None:
                l.postOrderDFS()
            if r != None:
                r.postOrderDFS()
            
            print(self.getValue())
    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    
    printTree(BT)
    print("Pre-order DFS:")
    BT.preOrderDFS()
    print("\nIn-order DFS:")
    BT.inOrderDFS()
    print("\nPost-order DFS:")
    BT.postOrderDFS()
# Out:
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (r)-> 6
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
# Pre-order DFS:
# Root
# 1
# 5a
# 5b
# 5c
# 2
# 3
# 4
# 5
# 6
#
# In-order DFS:
# 5a
# 1
# 5b
# 5c
# Root
# 4
# 3
# 5
# 2
# 6
#
# Post-order DFS:
# 5a
# 5c
# 5b
# 1
# 4
# 5
# 3
# 6
# 2
# Root

# %% [markdown]
# Compare the results above with the graph:
#
# ![](img/pract17/bintree_2.png)

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("1", color='blue')
G.add_node("2", color='blue')
G.add_node("3", color='blue')
G.add_node("4", color='black')
G.add_node("5", color='black')
G.add_node("5a", color='black')
G.add_node("5b", color='blue')
G.add_node("5c", color='black')
G.add_edge("Root" ,"2", color='blue')
G.add_edge("Root", "1", color='blue')
G.add_edge("2" ,"3", color='blue')
G.add_edge("2" ,"6", color='blue')
G.add_edge("3" ,"4", color='blue')
G.add_edge("3" ,"5", color='blue')
G.add_edge("1" ,"5a", color='blue')
G.add_edge("1" ,"5b", color='blue')
G.add_edge("5b" ,"5c", color='blue')
# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/bintree_2.png')

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("1", color='blue')
G.add_node("2", color='blue')
G.add_node("3", color='blue')
G.add_node("4", color='blue')
G.add_node("5", color='black')
G.add_node("5a", color='black')
G.add_node("5b", color='blue')
G.add_node("5c", color='black')
G.add_node("7", color='black')
G.add_node("8", color='black')
G.add_edge("Root" ,"2", color='blue')
G.add_edge("Root", "1", color='blue')
G.add_edge("2" ,"3", color='blue')
G.add_edge("2" ,"6", color='blue')
G.add_edge("3" ,"4", color='blue')
G.add_edge("3" ,"5", color='blue')
G.add_edge("1" ,"5a", color='blue')
G.add_edge("1" ,"5b", color='blue')
G.add_edge("5b" ,"5c", color='blue')
G.add_edge("4" ,"7", color='blue')
G.add_edge("4" ,"8", color='blue')

# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/bintree_2bis.png')

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("1", color='blue')
G.add_node("2", color='blue')
G.add_node("3", color='blue')
G.add_node("4", color='blue')
G.add_node("5", color='black')
G.add_node("6", color='blue')
G.add_node("5a", color='black')
G.add_node("5b", color='blue')
G.add_node("5c", color='black')
G.add_node("7", color='black')
G.add_node("8", color='black')
G.add_node("9", color='black')
G.add_node("10", color='black')
G.add_edge("Root" ,"2", color='blue')
G.add_edge("Root", "1", color='blue')
G.add_edge("2" ,"3", color='blue')
G.add_edge("2" ,"6", color='blue')
G.add_edge("3" ,"4", color='blue')
G.add_edge("3" ,"5", color='blue')
G.add_edge("1" ,"5a", color='blue')
G.add_edge("1" ,"5b", color='blue')
G.add_edge("5b" ,"5c", color='blue')
G.add_edge("4" ,"7", color='blue')
G.add_edge("4" ,"8", color='blue')
G.add_edge("6" ,"9", color='blue')
G.add_edge("6" ,"10", color='blue')

# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/bintree_2tris.png')

# %% [markdown]
# ### Binary Tree visits: BFS
#
# **Breadth first search** visits all the higher levels of a tree before going down. Basically, this search goes as wide as it can before going deep.
#
# This visit makes use of a queue: for each tree, it adds the left and right subtrees to the queue  and recursively visits them in the order they have been pushed into the queue.
#
# As said, implementations of BFS make use of a FIFO queue, in python we can use the efficient ```deque``` data structure that is implemented in the ```collections``` module (remember to import it first with ```from collections import deque``` and use ```deque.append``` to add at the end and ```deque.popleft``` to remove from the beginning).
#
# **Example:** Let's implement a BFS method and apply it to binary tree seen above.

# %%
from collections import deque

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self) 
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
   
    def BFS(self):
        if self != None:
            level = deque()
            level.append(self)
            
            
            while len(level) > 0:
                #print(len(level))
                cur = level.popleft()
                print(cur.getValue())
                r = cur.getRight()
                l = cur.getLeft()
                if l != None:
                    #print("from {} Appending: {}".format(cur.getValue(), 
                    #                                      l.getValue()))
                    level.append(l)
                if r != None:
                    level.append(r)
                    #print("from {} Appending: {}".format(cur.getValue(), 
                    #                                     r.getValue()))
    
    
    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    
    printTree(BT)
    print("BFS:")
    BT.BFS()
# Out:
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (r)-> 6
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
# BFS:
# Root
# 1
# 2
# 5a
# 5b
# 3
# 6
# 5c
# 4
# 5

# %% [markdown]
# Compare the results above with the graph:
#
# ![](img/pract17/bintree_2.png)

# %%
"""CODE NOT SHOWN!"""


#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("ROOT", color='red')
for i in range(0,3):
    G.add_node("Child_%i" % i, color='blue')
    G.add_node("Grandchild_%ia" % i, color='blue')
    G.add_node("Grandchild_%ib" % i, color='blue')
    G.add_node("Leaf_%i" % i, color='black')

    G.add_edge("ROOT", "Child_%i" % i, color='blue')
    G.add_edge("Child_%i" % i, "Grandchild_%ia" % i, color='blue')
    G.add_edge("Child_%i" % i, "Grandchild_%ib" % i, color='blue')
    if i % 2 == 0:
        G.add_edge("Grandchild_%ia" % i, "Leaf_%i" % i, color='black')        
        G.add_node("Leaf_%ia" %i, color = 'black')
        G.add_node("Leaf_%ib" %i, color = 'black')
        G.add_edge("Grandchild_%ib" % i, "Leaf_%ia" % i, color='black')
        G.add_edge("Grandchild_%ib" % i, "Leaf_%ib" % i, color='black')
    else:
        G.add_edge("Grandchild_%ib" % i, "Leaf_%i" % i, color='black')
        G.add_node("Leaf_%ia" %i, color = 'black')
        G.add_node("Leaf_%ib" %i, color = 'black')
        G.add_edge("Grandchild_%ia" % i, "Leaf_%ia" % i, color='black')
        G.add_edge("Grandchild_%ia" % i, "Leaf_%ib" % i, color='black')

# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/tree.png')

# %% [markdown]
# ### ADT: Generic Tree
#
# Generic Trees are like binary trees, but **each node can have more than 2 children**. One possible implementation is that each node (that is a subtree in itself) has a **value**, a link to its **parent** and a **list of children**.
#
# Another implementation is that each node has a **value**, a link to its **parent**, a link to its **next sibling** and a link to its **first child**:
#
# ![](img/pract17/genericTreePointers.png)
#
# We will be using this latter implementation of the tree.
#
# The **Generic Tree ADT** seen at lecture follows:
#
# ![](img/pract17/genericTreeADT.png)
#
# Given the following generic tree:
#
# ![](img/pract17/gentree_1.png)
#
#
# **Example:** Implement the a GenericTree class representing the ADT seen above and create the tree in the picture above.

# %%
# %reset -f 

class GenericTree:
    #This actually allows for forests
    #unless we force the root to have no siblings.
    def __init__(self, value):
        self.__data = value
        self.__parent = None
        self.__child = None
        self.__sibling = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self,newvalue):
        self.__data = newvalue
    
    def getParent(self):
        return self.__parent
    
    #not specified in ADT but needed
    #to add nodes
    def setParent(self, parent):
        self.__parent = parent
    
    def getLeftmostChild(self):
        return self.__child
    
    def getSibling(self):
        return self.__sibling
    #not specified in ADT but needed
    #to add nodes
    def setSibling(self,sib):
        self.__sibling = sib
        
    def insertSibling(self,sib):
        if type(sib) != GenericTree:
            raise TypeError("parameter sib is not a GenericTree")
        else:
            nextS = None
            if self.__sibling != None:
                nextS = self.__sibling  
            self.__sibling = sib
            sib.setParent(self.getParent())
            sib.setSibling(nextS)
        
            
    def insertChild(self,child):
        if type(child) != GenericTree:
            raise TypeError("parameter child is not a GenericTree")
        else:
            nextC = None
            print("from {} adding child --> {}".format(self.getValue(),
                                                       child.getValue()))
            if self.__child != None:
                nextC = self.__child
            child.setParent(self)
            child.setSibling(nextC)
            self.__child = child
           
    def deleteChild(self):
        if self.__child != None:
            #moves along the sibling structure of child
            self.__child = self.__child.getSibling()
        
    def deleteSibling(self):
        if self.__sibling != None:
            #moves along the sibling structure of the sibling
            self.__sibling = self.__sibling.getSibling()
            
if __name__ == "__main__":
    g = GenericTree("Root")
    g1 = GenericTree("First")
    g2 = GenericTree("Second")
    g3 = GenericTree("Third")
    g4 = GenericTree("Fourth")
    g5 = GenericTree("Fifth")
    g6 = GenericTree("Sixth")
    g7 = GenericTree("Seventh")
    g8 = GenericTree("Eighth")
    g9 = GenericTree("Ninth")
    g10 = GenericTree("Tenth")
    g11 = GenericTree("Eleventh")
    
    #root
    g.insertChild(g4)
    g.insertChild(g3)
    g.insertChild(g2)
    g.insertChild(g1)
    #second
    g2.insertChild(g6)
    g2.insertChild(g5)
    #fourth
    g4.insertChild(g7)
    g7.insertSibling(g11)
    #sixth
    g6.insertChild(g10)
    g6.insertChild(g9)
    g6.insertChild(g8)
    
    
    #let's print some stuff
    nodes = [g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11]
    for n in nodes:
        print("Node {}:".format(n.getValue()))
        par = n.getParent()
        if par != None:
            par = par.getValue()
        print("\t has parent: {}".format(par))
        c = n.getLeftmostChild()
        children = []
        if c != None:
            children.append(c.getValue())
            nc = c.getSibling()
            while nc != None:
                children.append(nc.getValue())
                nc = nc.getSibling()
        print("\t has children: {}".format(",".join(children)))
        s = n.getSibling()
        sibs = []
        if s != None:
            sibs.append(s.getValue())
            ns = s.getSibling()
            while ns != None:
                sibs.append(ns.getValue())
                ns = ns.getSibling()
        print("\t has next siblings: {}".format(",".join(sibs)))
# Out:
# from Root adding child --> Fourth
# from Root adding child --> Third
# from Root adding child --> Second
# from Root adding child --> First
# from Second adding child --> Sixth
# from Second adding child --> Fifth
# from Fourth adding child --> Seventh
# from Sixth adding child --> Tenth
# from Sixth adding child --> Ninth
# from Sixth adding child --> Eighth
# Node Root:
# 	 has parent: None
# 	 has children: First,Second,Third,Fourth
# 	 has next siblings:
# Node First:
# 	 has parent: Root
# 	 has children:
# 	 has next siblings: Second,Third,Fourth
# Node Second:
# 	 has parent: Root
# 	 has children: Fifth,Sixth
# 	 has next siblings: Third,Fourth
# Node Third:
# 	 has parent: Root
# 	 has children:
# 	 has next siblings: Fourth
# Node Fourth:
# 	 has parent: Root
# 	 has children: Seventh,Eleventh
# 	 has next siblings:
# Node Fifth:
# 	 has parent: Second
# 	 has children:
# 	 has next siblings: Sixth
# Node Sixth:
# 	 has parent: Second
# 	 has children: Eighth,Ninth,Tenth
# 	 has next siblings:
# Node Seventh:
# 	 has parent: Fourth
# 	 has children:
# 	 has next siblings: Eleventh
# Node Eighth:
# 	 has parent: Sixth
# 	 has children:
# 	 has next siblings: Ninth,Tenth
# Node Ninth:
# 	 has parent: Sixth
# 	 has children:
# 	 has next siblings: Tenth
# Node Tenth:
# 	 has parent: Sixth
# 	 has children:
# 	 has next siblings:
# Node Eleventh:
# 	 has parent: Fourth
# 	 has children:
# 	 has next siblings:

# %% [markdown]
# Note that the siblings list is actually unidirectional therefore "Second" does not any way to know that it is on the same level of "First".

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("First", color='black')
G.add_node("Second", color='blue')
G.add_node("Third", color='blue')
G.add_node("Fourth", color='blue')
G.add_node("Fifth", color='black')
G.add_node("Sixth", color='blue')
G.add_node("Seventh", color='black')
G.add_node("Eighth", color='black')
G.add_node("Ninth", color='black')
G.add_node("Tenth", color='black')
G.add_node("Eleventh", color='black')

G.add_edge("Root" ,"First", color='blue')
G.add_edge("Root", "Second", color='blue')
G.add_edge("Root" ,"Third", color='blue')
G.add_edge("Root" ,"Fourth", color='blue')
G.add_edge("Second" ,"Fifth", color='blue')
G.add_edge("Second" ,"Sixth", color='blue')
G.add_edge("Fourth" ,"Seventh", color='blue')
G.add_edge("Sixth" ,"Eighth", color='blue')
G.add_edge("Sixth" ,"Ninth", color='blue')
G.add_edge("Sixth" ,"Tenth", color='blue')
G.add_edge("Fourth" ,"Eleventh", color='blue')
# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/gentree_1.png')

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Modify the BinaryTree class adding a ```depth``` parameter counting, for each subtree, its depth (i.e. distance from the root of the tree). Note that you have to update properly the depth when inserting a new node. Add a ```getDepth``` and ```setDepth``` method too.
#
# If needed, you can download the code of the  original BinaryTree class here: [BinaryTree.py](file_samples/BinaryTree.py).
#
# a. Test the code printing the depth of all the nodes of the binary graph:
#
# ![](img/pract17/bintree_2bis.png)
#
# that can be created with:
#
# ```
# BT = BinaryTree("Root")
# bt1 = BinaryTree(1)
# bt2 = BinaryTree(2)
# bt3 = BinaryTree(3)
# bt4 = BinaryTree(4)
# bt5 = BinaryTree(5)
# bt6 = BinaryTree(6)
# bt5a = BinaryTree("5a")
# bt5b = BinaryTree("5b")
# bt5c = BinaryTree("5c")
# bt7 = BinaryTree(7)
# bt8 = BinaryTree(8)
# BT.insertLeft(bt1)
# BT.insertRight(bt2)
# bt2.insertLeft(bt3)
# bt3.insertLeft(bt4)
# bt3.insertRight(bt5)
# bt2.insertRight(bt6)
# bt1.insertRight(bt5b)
# bt1.insertLeft(bt5a)
# bt5b.insertRight(bt5c)
# bt4.insertRight(bt7)
# bt4.insertLeft(bt8)
# ```
# <div class="tggle" onclick="toggleVisibility('ex1');">Show/Hide Solution</div>
# <div id="ex1" style="display:none;">

# %%
# %reset -f


class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
   
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
     # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
            self.t.d = self.t.d + 1
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None


    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    bt7 = BinaryTree(7)
    bt8 = BinaryTree(8)
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    bt4.insertRight(bt7)
    bt4.insertLeft(bt8)

    nodeList = [BT,bt1,bt2,bt3,bt4, bt5, bt5a, bt5b, 
                bt5c, bt6, bt7, bt8]
    for node in nodeList:
        if node != None:
            print("Node {} has depth: {}".format(node.getValue(), 
                                                 node.getDepth()))
# Out:
# Node Root has depth: 0
# Node 1 has depth: 1
# Node 2 has depth: 1
# Node 3 has depth: 2
# Node 4 has depth: 3
# Node 5 has depth: 3
# Node 5a has depth: 2
# Node 5b has depth: 2
# Node 5c has depth: 3
# Node 6 has depth: 2
# Node 7 has depth: 4
# Node 8 has depth: 4

# %% [markdown]
# </div>

# %% [markdown]
# 2. The width of a binary tree T is the largest number of nodes that belong to the same level. The minimal height of a binary tree T is the minimal distance between the root and its closest leaf in its subtree. This distance is counted in number of nodes.
#
# Given the BinaryTree defined above:
#
# a. Write a function ```getWidth(T)``` that given a tree T, returns the width of T. Hint: get all nodes at each level and count them.
#
# b. Write a function ```getMinHeight(T)``` that given a tree T, returns the minimal height of T. Hint: stop at first level with a leaf (similar to previous function).
#
# c. Write a function ```nodesAtLevel(T,k)``` that given a binary tree T and an integer k, returns the number of nodes at level k.
#
# Test the functions with the following binary graph:
#
# ![](img/pract17/bintree_2tris.png)
#
# that can be created with:
#
# ```
# BT = BinaryTree("Root")
# bt1 = BinaryTree(1)
# bt2 = BinaryTree(2)
# bt3 = BinaryTree(3)
# bt4 = BinaryTree(4)
# bt5 = BinaryTree(5)
# bt6 = BinaryTree(6)
# bt5a = BinaryTree("5a")
# bt5b = BinaryTree("5b")
# bt5c = BinaryTree("5c")
# bt7 = BinaryTree(7)
# bt8 = BinaryTree(8)
# bt9 = BinaryTree(9)
# bt10 = BinaryTree(10)
# BT.insertLeft(bt1)
# BT.insertRight(bt2)
# bt2.insertLeft(bt3)
# bt3.insertLeft(bt4)
# bt3.insertRight(bt5)
# bt2.insertRight(bt6)
# bt1.insertRight(bt5b)
# bt1.insertLeft(bt5a)
# bt5b.insertRight(bt5c)
# bt4.insertRight(bt7)
# bt4.insertLeft(bt8)
# bt6.insertRight(bt10)
# bt6.insertLeft(bt9)
# ```
#
# <div class="tggle" onclick="toggleVisibility('ex2');">Show/Hide Solution</div>
# <div id="ex2" style="display:none;">

# %%
# %reset -f 

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
            
            
        
def getWidth(tree):
    """gets the width of the tree"""
    if tree == None:
        return 0
    
    level = [tree]
    res = 1
    while len(level) > 0:
        tmp = []
        for t in level:
            r = t.getRight()
            l = t.getLeft()
            if r != None:
                tmp.append(r)
            if l != None:
                tmp.append(l)
        res = max(res,len(tmp))
        level = tmp
        
    return res

def getMinHeight(tree):
    """gets the minimum height of the tree in nodes"""
    if tree == None:
        return 0
    
    level = [tree]
    res = 1
    while len(level) > 0:
        tmp = []
        for t in level:
            r = t.getRight()
            l = t.getLeft()
            if r == None and l == None:
                return res
            else:
                if r != None:
                    tmp.append(r)
                if l != None:
                    tmp.append(l)
        level = tmp
        res += 1
    return res

def nodesAtLevel(tree,k):
    """returns the number of nodes at level k"""
    if tree == None:
        return 0
    
    level = [tree]
    cnt = 0
    while cnt != k and len(level) > 0:
        tmp = []
        for t in level:
            r = t.getRight()
            l = t.getLeft()
            if l != None:
                tmp.append(l)
            if r != None:
                tmp.append(r)
                
        level = tmp
        cnt += 1
    if len(level) == 0:
        return None
    else:
        vals = [x.getValue() for x in level if x != None]
        return vals
     
    
if __name__ == "__main__":

    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    bt7 = BinaryTree(7)
    bt8 = BinaryTree(8)
    bt9 = BinaryTree(9)
    bt10 = BinaryTree(10)
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    bt4.insertRight(bt7)
    bt4.insertLeft(bt8)
    bt6.insertRight(bt10)
    bt6.insertLeft(bt9)
    
    print("The width of BT is {}".format(getWidth(BT)))
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
    for i in range(0,6):
        print("Nodes at level {}: {}".format(i,nodesAtLevel(BT,i)))
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
    bt1.deleteLeft()
    print("Deleting 5ca")
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
    bt5d = BinaryTree("5d")
    bt5c.insertLeft(bt5d)
    print("Adding 5d as left child of 5c")
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
# Out:
# The width of BT is 5
# The minimum height of BT is 3
# Nodes at level 0: ['Root']
# Nodes at level 1: [1, 2]
# Nodes at level 2: ['5a', '5b', 3, 6]
# Nodes at level 3: ['5c', 4, 5, 9, 10]
# Nodes at level 4: [8, 7]
# Nodes at level 5: None
# The minimum height of BT is 3
# Deleting 5ca
# The minimum height of BT is 4
# Adding 5d as left child of 5c
# The minimum height of BT is 4

# %% [markdown]
# </div>

# %% [markdown]
# 3. Given the BinaryTree used so far, implement a ```getCommonAncestor(n1,n2)``` method that gets the common ancestor between the two nodes n1 and n2.
#
# For example, considering the graph above:
#
# ```
# getCommonAncestor(7,5) = 3
# getCommonAncestor(7,10) = 2
# getCommonAncestor(8,5b) = Root
# getCommonAncestor(8,3) = 3
# ```
# <div class="tggle" onclick="toggleVisibility('ex3');">Show/Hide Solution</div>
# <div id="ex3" style="display:none;">

# %%
# %reset -f 

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
            
            
        
def getCommonAncestor( node1, node2):
    if node1 == node2:
        return node1
    
    if node1 == None or node2 == None:
        return None
    n1anc = set()
    n1anc.add(node1)
    
    anc = node1.getParent()
    while anc != None:
        n1anc.add(anc)
        anc = anc.getParent()
    
    anc = node2
    while anc != None:
        if anc in n1anc:
            return anc
        else:
            anc = anc.getParent()
    

    
if __name__ == "__main__":
    

    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    bt7 = BinaryTree(7)
    bt8 = BinaryTree(8)
    bt9 = BinaryTree(9)
    bt10 = BinaryTree(10)
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    bt4.insertRight(bt7)
    bt4.insertLeft(bt8)
    bt6.insertRight(bt10)
    bt6.insertLeft(bt9)
    
    ca = getCommonAncestor(bt7,bt5)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt7.getValue(),
                                                  bt5.getValue(),
                                                  ca))
    ca = getCommonAncestor(bt7,bt10)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt7.getValue(),
                                                  bt10.getValue(),
                                                  ca))
    ca = getCommonAncestor(bt7,bt8)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt7.getValue(),
                                                  bt8.getValue(),
                                                  ca))
    
    ca = getCommonAncestor(bt5b,bt8)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt5b.getValue(),
                                                  bt8.getValue(),
                                                  ca))
    
    ca = getCommonAncestor(bt3,bt8)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt3.getValue(),
                                                  bt8.getValue(),
                                                  ca))
# Out:
# The CA between 7 and 5 is: 3
# The CA between 7 and 10 is: 2
# The CA between 7 and 8 is: 4
# The CA between 5b and 8 is: Root
# The CA between 3 and 8 is: 3

# %% [markdown]
# </div>

# %% [markdown]
# 4. A Binary Search Tree, is binary tree with the following properties:
#
# a. The left subtree of a node contains only nodes with values lower than that of the node.
#
# b. The right subtree of a node contains only nodes with values greater than the node’s.
#
# c. No duplicate nodes are allowed.
#
#
# Implement:
#
# 1. a function ```BST = createBST(inList)``` that gets a list of integers (or strings) and returns a BinaryTree that is a Binary Search Tree;
#
# 2. a search function ```searchBST(BST, element)``` that gets an integer (or string) and checks if it is present in the Binary Search Tree.
#
# 3. modify the ```inOrderDFS(self)``` method to return a list of visited nodes in in-order depth first search. Test the method by printing the first 100 elements to show that they are actually sorted (this is a sorting algorithm effectively!);
#
# Test the code with the following ```intList```:
#
# ```
# import random
# intList = []
# for i in range(1000):
#     inList.append(random.randint(0,10000))
# ```
#
# NOTE: This solution shows you how to plot a graph (makes use of pygraphviz, which is an off-topic for this course). You can see a sample output of the plot here [BST_test.png](img/pract17/BST_test.png)
#
#
# <div class="tggle" onclick="toggleVisibility('ex4');">Show/Hide Solution</div>
# <div id="ex4" style="display:none;">

# %%
# %reset -f

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
        
    def inOrderDFS(self):
        ret = []
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            if l != None:
                ret.extend(l.inOrderDFS())
            ret.append(self.getValue())
            
            if r != None:
                ret.extend(r.inOrderDFS())
        return ret

def createBST(intList):
    BST = None
    if len(inList) > 0:
        BST = BinaryTree(inList[0])
        for el in intList[1:]:
            cur_el = BST
            alreadyPresent = False
            prev_el = None
            while cur_el != None:
                prev_el = cur_el
                cv = cur_el.getValue()
                if  cv > el:
                    cur_el = cur_el.getLeft()
                elif cv < el:
                    cur_el = cur_el.getRight()
                else:
                    #cv == el (el is already present)
                    #not allowed by rule c. skip it
                    alreadyPresent = True
                    #print("El {} already present".format(el))
                    break
                
                
            if not alreadyPresent:
                node = BinaryTree(el)
                node.setParent(prev_el)
                if prev_el.getValue() > el:
                    prev_el.insertLeft(node)
                else:
                    prev_el.insertRight(node)
                
        
    return BST
    
def searchBST(BST, element):
    if BST == None or element == None:
        return False
    else:
        cur_el = BST
        while cur_el != None:
            if cur_el.getValue() == element:
                return True
            else:
                if cur_el.getValue()> element:
                    cur_el = cur_el.getLeft()
                else:
                    cur_el = cur_el.getRight()
        
        return False


def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
     


def plotGraph(tree):    
    #uses pygraphviz 
    G=pgv.AGraph(directed=True)
    
    levels = [tree]
    while len(levels) > 0:
        cur_n = levels.pop()
        if cur_n != None:
            G.add_node(cur_n.getValue(), color = 'black')
            r = cur_n.getRight()
            l = cur_n.getLeft()
            if l != None:
                G.add_node(l.getValue(), color = 'black')
                G.add_edge(cur_n.getValue(), l.getValue())
                levels.append(l)
            if r != None:
                G.add_node(r.getValue(), color = 'black')
                G.add_edge(cur_n.getValue(), r.getValue())
                levels.append(r)
    G.layout(prog='dot') # use dot
    #In the following, the path of the graph. Change
    #it to your liking
    G.draw('img/pract17/BST_test.png')
       
    
if __name__ == "__main__":
    import random
    import pygraphviz as pgv
    #import time 
    inList = []
    for i in range(1000):
        inList.append(random.randint(0,10000))
        
    BST = createBST(inList)
    
    #printTree(BST)
    plotGraph(BST)
    for i in range(1000):
        v = random.randint(0,10000)
        #s_t = time.time()
        ok = searchBST(BST, v)
        #e_t = time.time()
        okL = v in inList
        #e_t2 = time.time()
        print("el {} : present? {}".format(v, ok))
        #print("Time BST:{:.6f} list:{:.6f}".format(e_t - s_t,
        #                                           e_t2 - e_t
        #                                            ))
        assert(ok == okL)
    sorted = BST.inOrderDFS()
    print("\nIn order DFS (first 100 elements):")
    print(sorted[0:100])
# Out:
# el 6054 : present? False
# el 4235 : present? False
# el 7214 : present? False
# el 7697 : present? False
# el 427 : present? False
# el 16 : present? False
# el 1578 : present? False
# el 6128 : present? False
# el 1698 : present? False
# el 4146 : present? False
# el 7594 : present? False
# el 5695 : present? False
# el 4170 : present? True
# el 9807 : present? False
# el 2274 : present? False
# el 5659 : present? True
# el 8584 : present? False
# el 4957 : present? True
# el 890 : present? False
# el 4075 : present? False
# el 3700 : present? False
# el 3735 : present? False
# el 1442 : present? False
# el 3203 : present? False
# el 4954 : present? True
# el 535 : present? False
# el 6259 : present? False
# el 4014 : present? False
# el 8728 : present? False
# el 8667 : present? False
# el 1837 : present? False
# el 7122 : present? False
# el 172 : present? False
# el 5004 : present? False
# el 6264 : present? False
# el 8415 : present? False
# el 5015 : present? False
# el 7878 : present? False
# el 8043 : present? False
# el 3373 : present? False
# el 7104 : present? False
# el 3937 : present? True
# el 4575 : present? False
# el 9964 : present? False
# el 8353 : present? False
# el 9250 : present? True
# el 6163 : present? False
# el 8138 : present? False
# el 920 : present? False
# el 1683 : present? False
# el 1753 : present? False
# el 5971 : present? False
# el 3503 : present? False
# el 5681 : present? False
# el 7668 : present? False
# el 8433 : present? False
# el 4501 : present? False
# el 5172 : present? False
# el 1101 : present? False
# el 9957 : present? False
# el 6233 : present? False
# el 9165 : present? False
# el 8531 : present? False
# el 2312 : present? False
# el 4710 : present? False
# el 991 : present? False
# el 1815 : present? False
# el 2123 : present? False
# el 7555 : present? False
# el 8679 : present? False
# el 5625 : present? False
# el 3943 : present? False
# el 5478 : present? False
# el 172 : present? False
# el 6308 : present? False
# el 5087 : present? False
# el 418 : present? False
# el 8908 : present? False
# el 478 : present? True
# el 7691 : present? False
# el 2706 : present? False
# el 3580 : present? False
# el 8642 : present? False
# el 447 : present? False
# el 1188 : present? True
# el 9913 : present? False
# el 1921 : present? False
# el 6716 : present? False
# el 3646 : present? False
# el 5893 : present? False
# el 885 : present? False
# el 9874 : present? False
# el 3720 : present? False
# el 4251 : present? False
# el 8960 : present? False
# el 2409 : present? False
# el 5863 : present? False
# el 9942 : present? False
# el 4818 : present? False
# el 6281 : present? False
# el 5151 : present? False
# el 6815 : present? False
# el 4078 : present? False
# el 9168 : present? False
# el 6701 : present? False
# el 4423 : present? True
# el 3050 : present? False
# el 3436 : present? False
# el 1270 : present? True
# el 1895 : present? False
# el 4945 : present? True
# el 2322 : present? False
# el 1205 : present? False
# el 9204 : present? False
# el 4534 : present? False
# el 8893 : present? False
# el 1071 : present? False
# el 3773 : present? False
# el 3474 : present? False
# el 3716 : present? False
# el 5639 : present? False
# el 8035 : present? False
# el 372 : present? False
# el 8054 : present? False
# el 2740 : present? False
# el 1379 : present? False
# el 7862 : present? False
# el 1532 : present? False
# el 3840 : present? False
# el 3620 : present? True
# el 8396 : present? False
# el 4769 : present? False
# el 8699 : present? False
# el 2999 : present? False
# el 2898 : present? False
# el 681 : present? False
# el 7773 : present? False
# el 7630 : present? False
# el 4731 : present? False
# el 534 : present? False
# el 5607 : present? False
# el 8386 : present? False
# el 8917 : present? False
# el 1944 : present? False
# el 3737 : present? False
# el 5830 : present? False
# el 3822 : present? True
# el 9146 : present? False
# el 7676 : present? False
# el 9699 : present? False
# el 5465 : present? False
# el 7566 : present? False
# el 4534 : present? False
# el 9326 : present? False
# el 3300 : present? False
# el 2095 : present? False
# el 4668 : present? False
# el 7087 : present? False
# el 1866 : present? False
# el 6781 : present? False
# el 6296 : present? True
# el 2784 : present? False
# el 1613 : present? True
# el 9083 : present? False
# el 780 : present? False
# el 5890 : present? False
# el 6853 : present? False
# el 6605 : present? False
# el 1940 : present? False
# el 4378 : present? False
# el 2168 : present? False
# el 9495 : present? False
# el 383 : present? False
# el 8975 : present? False
# el 7651 : present? False
# el 2572 : present? False
# el 8608 : present? False
# el 6045 : present? False
# el 6986 : present? False
# el 9838 : present? False
# el 1210 : present? False
# el 442 : present? False
# el 5963 : present? False
# el 4650 : present? False
# el 4128 : present? False
# el 1863 : present? False
# el 2154 : present? False
# el 6670 : present? False
# el 7587 : present? False
# el 4086 : present? True
# el 6047 : present? False
# el 6533 : present? False
# el 8008 : present? False
# el 9443 : present? False
# el 7079 : present? False
# el 61 : present? False
# el 4695 : present? False
# el 2810 : present? True
# el 2071 : present? True
# el 5423 : present? False
# el 5976 : present? True
# el 2985 : present? False
# el 6856 : present? False
# el 5157 : present? False
# el 4490 : present? False
# el 3984 : present? False
# el 6027 : present? False
# el 8307 : present? False
# el 6686 : present? False
# el 1001 : present? False
# el 5319 : present? True
# el 352 : present? False
# el 3131 : present? False
# el 5496 : present? False
# el 2934 : present? False
# el 9635 : present? False
# el 9407 : present? False
# el 1187 : present? False
# el 3845 : present? False
# el 2287 : present? False
# el 7905 : present? False
# el 1321 : present? False
# el 5435 : present? False
# el 5614 : present? False
# el 6551 : present? False
# el 1100 : present? False
# el 4090 : present? False
# el 7725 : present? False
# el 6906 : present? False
# el 352 : present? False
# el 9995 : present? False
# el 9654 : present? False
# el 2731 : present? False
# el 2835 : present? True
# el 8972 : present? False
# el 4761 : present? False
# el 9256 : present? False
# el 7555 : present? False
# el 3405 : present? False
# el 4534 : present? False
# el 7000 : present? False
# el 2897 : present? False
# el 1567 : present? False
# el 5936 : present? False
# el 5686 : present? False
# el 3419 : present? False
# el 4196 : present? False
# el 4785 : present? False
# el 5300 : present? False
# el 5361 : present? False
# el 6388 : present? False
# el 5872 : present? False
# el 8054 : present? False
# el 9203 : present? False
# el 4607 : present? False
# el 9357 : present? True
# el 9040 : present? True
# el 6280 : present? False
# el 3772 : present? False
# el 4370 : present? False
# el 7474 : present? True
# el 5045 : present? False
# el 2952 : present? False
# el 4021 : present? False
# el 7495 : present? False
# el 1727 : present? False
# el 158 : present? False
# el 5859 : present? False
# el 1111 : present? False
# el 9604 : present? False
# el 2580 : present? False
# el 8561 : present? False
# el 7197 : present? True
# el 6891 : present? False
# el 6043 : present? False
# el 353 : present? False
# el 6892 : present? False
# el 3036 : present? False
# el 5216 : present? False
# el 7339 : present? False
# el 7390 : present? False
# el 1351 : present? False
# el 4317 : present? False
# el 3095 : present? False
# el 4192 : present? False
# el 5626 : present? False
# el 379 : present? False
# el 7610 : present? False
# el 2768 : present? False
# el 4298 : present? False
# el 1662 : present? False
# el 4572 : present? False
# el 9663 : present? False
# el 870 : present? False
# el 9425 : present? False
# el 7798 : present? False
# el 5615 : present? False
# el 5436 : present? False
# el 7965 : present? False
# el 5708 : present? False
# el 8689 : present? False
# el 3070 : present? False
# el 5845 : present? False
# el 3661 : present? True
# el 6120 : present? False
# el 4480 : present? False
# el 8551 : present? False
# el 4734 : present? False
# el 9669 : present? False
# el 2591 : present? False
# el 4499 : present? False
# el 2747 : present? False
# el 8497 : present? False
# el 4598 : present? False
# el 4432 : present? False
# el 435 : present? False
# el 9310 : present? False
# el 5557 : present? False
# el 4091 : present? False
# el 9383 : present? False
# el 5490 : present? False
# el 4943 : present? False
# el 5514 : present? False
# el 9182 : present? False
# el 7575 : present? False
# el 6269 : present? False
# el 2468 : present? False
# el 1711 : present? False
# el 1945 : present? False
# el 9697 : present? False
# el 1780 : present? True
# el 1779 : present? False
# el 5669 : present? False
# el 3834 : present? False
# el 1134 : present? False
# el 1579 : present? False
# el 5709 : present? False
# el 3196 : present? False
# el 250 : present? False
# el 4941 : present? False
# el 9859 : present? False
# el 8921 : present? False
# el 4830 : present? False
# el 5671 : present? False
# el 4747 : present? True
# el 6974 : present? True
# el 8986 : present? False
# el 9820 : present? False
# el 5365 : present? False
# el 5919 : present? False
# el 8861 : present? False
# el 953 : present? False
# el 137 : present? False
# el 7199 : present? False
# el 8465 : present? False
# el 7781 : present? False
# el 1112 : present? False
# el 8468 : present? False
# el 2684 : present? False
# el 3664 : present? False
# el 1166 : present? False
# el 9383 : present? False
# el 4030 : present? False
# el 3097 : present? False
# el 5055 : present? False
# el 3345 : present? False
# el 6889 : present? False
# el 5166 : present? False
# el 409 : present? False
# el 743 : present? True
# el 5889 : present? False
# el 238 : present? False
# el 1219 : present? False
# el 3430 : present? False
# el 2159 : present? False
# el 1267 : present? False
# el 5430 : present? False
# el 2319 : present? False
# el 6408 : present? False
# el 3013 : present? False
# el 6417 : present? False
# el 4803 : present? True
# el 4941 : present? False
# el 7347 : present? False
# el 6242 : present? False
# el 6216 : present? False
# el 9146 : present? False
# el 1477 : present? False
# el 2852 : present? False
# el 1959 : present? False
# el 5329 : present? False
# el 6203 : present? False
# el 5601 : present? False
# el 7291 : present? False
# el 3358 : present? False
# el 8277 : present? False
# el 5796 : present? False
# el 2354 : present? False
# el 4082 : present? False
# el 7205 : present? False
# el 6275 : present? False
# el 6871 : present? False
# el 9220 : present? False
# el 1269 : present? False
# el 9296 : present? False
# el 2106 : present? False
# el 7942 : present? False
# el 4754 : present? False
# el 7232 : present? False
# el 3344 : present? False
# el 3878 : present? False
# el 5049 : present? False
# el 519 : present? False
# el 8376 : present? False
# el 9110 : present? False
# el 1594 : present? False
# el 7984 : present? False
# el 1784 : present? False
# el 1656 : present? False
# el 300 : present? False
# el 8476 : present? False
# el 6800 : present? False
# el 2642 : present? False
# el 3778 : present? False
# el 89 : present? False
# el 2487 : present? False
# el 5006 : present? False
# el 9575 : present? False
# el 5677 : present? False
# el 5991 : present? False
# el 5012 : present? False
# el 4718 : present? False
# el 4414 : present? False
# el 5895 : present? False
# el 7987 : present? True
# el 661 : present? False
# el 3263 : present? True
# el 5961 : present? False
# el 4417 : present? False
# el 3695 : present? False
# el 2132 : present? False
# el 1371 : present? False
# el 6880 : present? False
# el 8930 : present? False
# el 9448 : present? False
# el 1629 : present? False
# el 6583 : present? True
# el 1640 : present? True
# el 7127 : present? False
# el 8116 : present? False
# el 637 : present? False
# el 1869 : present? False
# el 489 : present? False
# el 7582 : present? False
# el 9760 : present? False
# el 3446 : present? False
# el 7482 : present? False
# el 2651 : present? False
# el 1094 : present? False
# el 9042 : present? False
# el 7621 : present? False
# el 994 : present? False
# el 1746 : present? False
# el 9548 : present? False
# el 5732 : present? True
# el 4850 : present? False
# el 6959 : present? False
# el 4338 : present? False
# el 3539 : present? False
# el 4129 : present? False
# el 5631 : present? False
# el 1775 : present? False
# el 5876 : present? False
# el 2776 : present? False
# el 2422 : present? False
# el 5778 : present? False
# el 9449 : present? True
# el 154 : present? False
# el 5891 : present? False
# el 1230 : present? False
# el 9313 : present? False
# el 5539 : present? False
# el 8035 : present? False
# el 5363 : present? False
# el 3486 : present? False
# el 1458 : present? True
# el 8094 : present? False
# el 449 : present? True
# el 6896 : present? False
# el 5086 : present? False
# el 3030 : present? False
# el 9741 : present? False
# el 8321 : present? False
# el 6045 : present? False
# el 99 : present? False
# el 2751 : present? False
# el 6048 : present? False
# el 980 : present? False
# el 8004 : present? False
# el 1367 : present? True
# el 6262 : present? False
# el 2897 : present? False
# el 4579 : present? False
# el 9583 : present? False
# el 1779 : present? False
# el 978 : present? False
# el 226 : present? False
# el 5215 : present? False
# el 819 : present? False
# el 5763 : present? False
# el 9417 : present? False
# el 2241 : present? False
# el 5602 : present? False
# el 9899 : present? False
# el 9055 : present? False
# el 5068 : present? True
# el 9135 : present? False
# el 5096 : present? False
# el 8141 : present? False
# el 7291 : present? False
# el 4237 : present? False
# el 4131 : present? False
# el 1850 : present? True
# el 4383 : present? False
# el 8280 : present? False
# el 3226 : present? True
# el 7877 : present? False
# el 4193 : present? False
# el 2002 : present? False
# el 331 : present? False
# el 7094 : present? False
# el 3968 : present? False
# el 9681 : present? False
# el 8058 : present? True
# el 2475 : present? False
# el 4118 : present? False
# el 5874 : present? False
# el 7335 : present? False
# el 2237 : present? False
# el 7747 : present? False
# el 9768 : present? False
# el 249 : present? False
# el 1831 : present? False
# el 5768 : present? False
# el 3277 : present? False
# el 4013 : present? False
# el 2198 : present? False
# el 5095 : present? False
# el 6297 : present? False
# el 1989 : present? False
# el 2775 : present? False
# el 9907 : present? False
# el 8880 : present? False
# el 714 : present? False
# el 3610 : present? True
# el 4456 : present? False
# el 6384 : present? True
# el 742 : present? False
# el 2165 : present? False
# el 5318 : present? False
# el 630 : present? False
# el 2441 : present? False
# el 6680 : present? False
# el 5808 : present? False
# el 5815 : present? False
# el 4669 : present? False
# el 4157 : present? False
# el 6975 : present? False
# el 8279 : present? False
# el 5133 : present? False
# el 1353 : present? False
# el 8985 : present? False
# el 1896 : present? False
# el 7644 : present? False
# el 1031 : present? False
# el 5993 : present? False
# el 1348 : present? False
# el 4583 : present? False
# el 6230 : present? False
# el 1900 : present? False
# el 9433 : present? False
# el 3568 : present? False
# el 5346 : present? True
# el 3490 : present? True
# el 968 : present? False
# el 5935 : present? True
# el 1018 : present? False
# el 6307 : present? False
# el 3019 : present? False
# el 4995 : present? False
# el 1631 : present? False
# el 4984 : present? False
# el 9007 : present? False
# el 1515 : present? False
# el 7775 : present? False
# el 5735 : present? False
# el 4480 : present? False
# el 8824 : present? False
# el 466 : present? False
# el 2568 : present? False
# el 5425 : present? False
# el 8480 : present? True
# el 9214 : present? False
# el 9380 : present? False
# el 3356 : present? False
# el 8132 : present? False
# el 9799 : present? False
# el 258 : present? False
# el 8040 : present? False
# el 5132 : present? False
# el 4902 : present? False
# el 2783 : present? False
# el 29 : present? False
# el 9422 : present? False
# el 3755 : present? False
# el 291 : present? False
# el 6066 : present? False
# el 1064 : present? False
# el 964 : present? False
# el 8758 : present? False
# el 1246 : present? True
# el 9046 : present? True
# el 5978 : present? False
# el 4509 : present? True
# el 3525 : present? False
# el 7504 : present? False
# el 8428 : present? False
# el 2508 : present? False
# el 8667 : present? False
# el 5548 : present? False
# el 6881 : present? False
# el 2550 : present? True
# el 3050 : present? False
# el 7016 : present? False
# el 5960 : present? False
# el 6462 : present? False
# el 4512 : present? False
# el 3109 : present? False
# el 6916 : present? False
# el 3104 : present? True
# el 823 : present? False
# el 6028 : present? False
# el 1674 : present? True
# el 9084 : present? False
# el 4717 : present? False
# el 7852 : present? False
# el 5550 : present? False
# el 5185 : present? False
# el 3046 : present? False
# el 9220 : present? False
# el 8314 : present? False
# el 623 : present? False
# el 3640 : present? False
# el 5725 : present? False
# el 7380 : present? False
# el 3209 : present? False
# el 2675 : present? False
# el 779 : present? False
# el 638 : present? False
# el 439 : present? False
# el 4558 : present? False
# el 2106 : present? False
# el 5187 : present? False
# el 7427 : present? False
# el 901 : present? False
# el 1832 : present? False
# el 1101 : present? False
# el 514 : present? False
# el 8792 : present? False
# el 8606 : present? False
# el 5280 : present? False
# el 1359 : present? False
# el 4532 : present? False
# el 2613 : present? False
# el 1065 : present? False
# el 2897 : present? False
# el 4226 : present? False
# el 2494 : present? False
# el 9398 : present? False
# el 6863 : present? False
# el 7966 : present? False
# el 2840 : present? False
# el 5874 : present? False
# el 9205 : present? False
# el 6766 : present? True
# el 5601 : present? False
# el 2407 : present? False
# el 4260 : present? False
# el 1736 : present? False
# el 392 : present? False
# el 5544 : present? False
# el 1507 : present? False
# el 5445 : present? False
# el 6857 : present? False
# el 2981 : present? True
# el 745 : present? False
# el 9374 : present? False
# el 751 : present? False
# el 3954 : present? False
# el 4734 : present? False
# el 9061 : present? False
# el 539 : present? False
# el 578 : present? False
# el 6948 : present? False
# el 2102 : present? True
# el 307 : present? False
# el 5239 : present? False
# el 5427 : present? False
# el 9282 : present? True
# el 1094 : present? False
# el 9915 : present? False
# el 150 : present? False
# el 453 : present? False
# el 8464 : present? False
# el 8832 : present? True
# el 1006 : present? False
# el 6081 : present? False
# el 7718 : present? False
# el 2261 : present? False
# el 439 : present? False
# el 8069 : present? False
# el 6620 : present? False
# el 1486 : present? False
# el 5181 : present? False
# el 8196 : present? False
# el 1249 : present? False
# el 9728 : present? False
# el 8694 : present? False
# el 9074 : present? False
# el 8371 : present? False
# el 5532 : present? False
# el 1808 : present? False
# el 1491 : present? False
# el 5549 : present? False
# el 8918 : present? False
# el 5048 : present? False
# el 1745 : present? False
# el 4661 : present? False
# el 2062 : present? False
# el 1949 : present? False
# el 5567 : present? False
# el 7419 : present? False
# el 1729 : present? False
# el 5238 : present? False
# el 6176 : present? False
# el 4969 : present? False
# el 6606 : present? False
# el 3558 : present? False
# el 2392 : present? False
# el 7549 : present? False
# el 9409 : present? False
# el 2416 : present? False
# el 7566 : present? False
# el 8491 : present? True
# el 5941 : present? True
# el 1095 : present? False
# el 7063 : present? False
# el 4033 : present? False
# el 1185 : present? False
# el 9051 : present? False
# el 4256 : present? False
# el 9828 : present? False
# el 2938 : present? False
# el 3600 : present? False
# el 1542 : present? False
# el 7751 : present? False
# el 2750 : present? False
# el 8951 : present? False
# el 277 : present? False
# el 6732 : present? False
# el 2612 : present? False
# el 8409 : present? False
# el 4860 : present? False
# el 6502 : present? False
# el 3391 : present? False
# el 9799 : present? False
# el 2865 : present? False
# el 3568 : present? False
# el 3638 : present? False
# el 8419 : present? False
# el 3690 : present? False
# el 6275 : present? False
# el 4245 : present? False
# el 2839 : present? False
# el 3137 : present? False
# el 3389 : present? False
# el 4414 : present? False
# el 3614 : present? False
# el 6726 : present? False
# el 4853 : present? False
# el 1873 : present? False
# el 9432 : present? False
# el 3227 : present? False
# el 9641 : present? False
# el 6638 : present? False
# el 7297 : present? False
# el 9553 : present? False
# el 5374 : present? False
# el 4375 : present? False
# el 729 : present? False
# el 7120 : present? False
# el 7106 : present? False
# el 7409 : present? False
# el 3564 : present? False
# el 5511 : present? False
# el 6528 : present? False
# el 9963 : present? False
# el 9285 : present? False
# el 4286 : present? False
# el 839 : present? True
# el 4770 : present? False
# el 1927 : present? False
# el 8567 : present? True
# el 3689 : present? False
# el 8117 : present? False
# el 9831 : present? False
# el 4636 : present? False
# el 2705 : present? False
# el 5672 : present? False
# el 8034 : present? False
# el 2122 : present? False
# el 5915 : present? False
# el 9936 : present? False
# el 5442 : present? False
# el 6858 : present? False
# el 3995 : present? True
# el 826 : present? False
# el 342 : present? False
# el 702 : present? False
# el 1794 : present? False
# el 6449 : present? False
# el 9576 : present? False
# el 7058 : present? True
# el 6259 : present? False
# el 8705 : present? False
# el 1056 : present? False
# el 3949 : present? False
# el 4364 : present? False
# el 4907 : present? False
# el 9449 : present? True
# el 806 : present? False
# el 2188 : present? True
# el 5200 : present? False
# el 2803 : present? False
# el 4889 : present? False
# el 4755 : present? False
# el 8102 : present? False
# el 2782 : present? True
# el 9028 : present? False
# el 750 : present? True
# el 3795 : present? False
# el 1445 : present? False
# el 8472 : present? False
# el 4112 : present? False
# el 8169 : present? True
# el 7182 : present? True
# el 255 : present? False
# el 844 : present? False
# el 3541 : present? False
# el 8975 : present? False
# el 2548 : present? False
# el 5673 : present? False
# el 4907 : present? False
# el 5815 : present? False
# el 9639 : present? False
# el 9490 : present? False
# el 7787 : present? False
# el 4883 : present? False
# el 4921 : present? False
# el 1472 : present? False
# el 9267 : present? False
# el 6064 : present? False
# el 3346 : present? False
# el 1962 : present? False
# el 3087 : present? True
# el 1766 : present? False
# el 1548 : present? False
# el 8416 : present? False
# el 9566 : present? False
# el 2737 : present? False
# el 6273 : present? False
# el 9766 : present? False
# el 3373 : present? False
# el 5824 : present? False
# el 6301 : present? False
# el 2859 : present? False
# el 5474 : present? False
# el 6822 : present? False
# el 2563 : present? False
# el 1559 : present? False
# el 772 : present? False
# el 9321 : present? False
# el 4502 : present? False
# el 4497 : present? False
# el 5234 : present? False
# el 6065 : present? False
# el 1253 : present? False
# el 1131 : present? False
# el 7936 : present? True
# el 6131 : present? False
# el 632 : present? False
# el 9305 : present? False
# el 5403 : present? True
# el 4380 : present? False
# el 4789 : present? False
# el 4859 : present? False
# el 6677 : present? False
# el 7008 : present? False
# el 4990 : present? False
# el 1428 : present? False
# el 4045 : present? False
# el 5378 : present? False
# el 9344 : present? False
# el 32 : present? False
# el 2970 : present? False
# el 6120 : present? False
# el 9447 : present? False
# el 4909 : present? False
# el 7417 : present? False
# el 165 : present? True
# el 2433 : present? False
# el 9380 : present? False
# el 9120 : present? False
# el 7610 : present? False
# el 7539 : present? False
# el 8610 : present? False
# el 5234 : present? False
# el 1803 : present? True
# el 1882 : present? False
# el 8848 : present? False
# el 9350 : present? False
# el 2442 : present? False
# el 2858 : present? False
# el 921 : present? False
# el 9201 : present? False
# el 7854 : present? False
# el 5539 : present? False
# el 8031 : present? True
# el 8379 : present? False
# el 3240 : present? False
# el 6420 : present? False
# el 9071 : present? False
# el 7725 : present? False
# el 9856 : present? False
# el 4077 : present? False
# el 8527 : present? False
# el 6066 : present? False
# el 8129 : present? False
# el 6420 : present? False
# el 2529 : present? False
# el 1356 : present? False
# el 3029 : present? False
# el 3438 : present? False
# el 7357 : present? False
# el 5181 : present? False
# el 8879 : present? False
# el 7986 : present? False
# el 8818 : present? True
# el 4921 : present? False
# el 1577 : present? False
# el 3233 : present? False
# el 1772 : present? False
# el 5828 : present? False
# el 2811 : present? False
# el 8812 : present? False
# el 4533 : present? False
# el 4557 : present? False
# el 6339 : present? True
# el 2420 : present? False
# el 8312 : present? False
# el 6263 : present? False
# el 356 : present? False
# el 1376 : present? False
# el 2388 : present? False
# el 2364 : present? False
# el 7207 : present? False
# el 4953 : present? False
# el 4613 : present? False
# el 3907 : present? True
# el 3932 : present? False
# el 5548 : present? False
# el 4548 : present? True
# el 9502 : present? False
# el 5869 : present? False
# el 5008 : present? True
# el 584 : present? False
# el 115 : present? False
# el 2658 : present? False
# el 3189 : present? False
# el 5428 : present? False
# el 7160 : present? False
# el 4225 : present? False
# el 2385 : present? False
# el 4799 : present? False
# el 4808 : present? False
# el 2006 : present? False
# el 9695 : present? False
# el 9010 : present? False
# el 3102 : present? False
# el 9565 : present? False
#
# In order DFS (first 100 elements):
# [5, 13, 22, 54, 65, 71, 76, 80, 84, 86, 94, 117, 128, 130, 131, 160, 164, 165, 176, 178, 179, 191, 217, 220, 245, 248, 261, 272, 274, 284, 288, 315, 317, 322, 338, 347, 366, 370, 377, 397, 423, 430, 432, 434, 449, 456, 468, 476, 478, 503, 528, 530, 545, 552, 558, 562, 566, 567, 576, 577, 593, 607, 633, 634, 649, 655, 670, 671, 684, 688, 701, 708, 710, 711, 731, 733, 735, 743, 750, 756, 757, 769, 774, 782, 789, 801, 829, 833, 837, 839, 860, 868, 874, 875, 876, 879, 908, 912, 919, 937]

# %% [markdown]
# </div>

# %% [markdown]
# 5. Implement the Generic Tree above without looking at the code.
#
# As a reminder, the connections of pointers are:
#
# ![](img/pract17/genericTreePointers.png)
#
# the ADT:
#
# ![](img/pract17/genericTreeADT.png)
#
# <div class="tggle" onclick="toggleVisibility('ex5');">Show/Hide Solution</div>
# <div id="ex5" style="display:none;">

# %% [markdown]
# check the code above.

# %% [markdown]
# </div>
